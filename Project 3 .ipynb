# %%
#import liberies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#data load
data=pd.read_csv(r"C:\Users\manju\Downloads\restaurant_customer_satisfaction.csv")

# %%
data.head(10)
# Out:
#    CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0         654   35    Male   83380         Weekly     27.829142
# 1         655   19    Male   43623         Rarely    115.408622
# 2         656   41  Female   83737         Weekly    106.693771
# 3         657   43    Male   96768         Rarely     43.508508
# 4         658   55  Female   67937        Monthly    148.084627
# 5         659   42  Female   28860        Monthly    111.064696
# 6         660   20  Female  131104         Weekly    120.236707
# 7         661   51  Female  137882         Weekly    160.979098
# 8         662   27    Male  149638         Weekly     56.558632
# 9         663   32  Female  136145         Weekly     65.753455
#
#   PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0          Chinese   Breakfast          3       Business  Takeaway
# 1         American      Dinner          1         Casual   Dine-in
# ...

# %%
data.tail(10)
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 1490        2144   20    Male  106717         Rarely    105.323720
# 1491        2145   47    Male   90569         Weekly    101.312053
# 1492        2146   20    Male   41041         Rarely     59.403047
# 1493        2147   62    Male  135684         Weekly    128.943101
# 1494        2148   25  Female  142332         Weekly    128.626784
# 1495        2149   39    Male  114857        Monthly    163.015254
# 1496        2150   37  Female  133506         Weekly    190.991911
# 1497        2151   46    Male  119159        Monthly    150.088604
# 1498        2152   24    Male   27970         Weekly    196.363626
# 1499        2153   51    Male  148333         Weekly    171.119498
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 1490           Indian   Breakfast          5         Casual  Takeaway
# 1491           Indian       Lunch          9         Casual  Takeaway
# ...

# %%
data.shape
# Out:
# (1500, 19)

# %%
data.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Income', 'VisitFrequency',
#        'AverageSpend', 'PreferredCuisine', 'TimeOfVisit', 'GroupSize',
#        'DiningOccasion', 'MealType', 'OnlineReservation', 'DeliveryOrder',
#        'LoyaltyProgramMember', 'WaitTime', 'ServiceRating', 'FoodRating',
#        'AmbianceRating', 'HighSatisfaction'],
#       dtype='object')

# %%
data.describe()
# Out:
#         CustomerID          Age         Income  AverageSpend    GroupSize  \
# count  1500.000000  1500.000000    1500.000000   1500.000000  1500.000000
# mean   1403.500000    43.832000   85921.890000    105.659004     5.035333
# std     433.157015    14.967157   38183.051749     52.381849     2.558864
# min     654.000000    18.000000   20012.000000     10.306127     1.000000
# 25%    1028.750000    31.750000   52444.000000     62.287907     3.000000
# 50%    1403.500000    44.000000   85811.000000    104.626408     5.000000
# 75%    1778.250000    57.000000  119159.250000    148.649330     7.000000
# max    2153.000000    69.000000  149875.000000    199.973527     9.000000
#
#        OnlineReservation  DeliveryOrder  LoyaltyProgramMember     WaitTime  \
# count        1500.000000    1500.000000           1500.000000  1500.000000
# mean            0.296667       0.405333              0.480000    30.163550
# std             0.456941       0.491120              0.499766    17.214184
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            1500 non-null   int64
#  1   Age                   1500 non-null   int64
#  2   Gender                1500 non-null   object
#  3   Income                1500 non-null   int64
#  4   VisitFrequency        1500 non-null   object
#  5   AverageSpend          1500 non-null   float64
#  6   PreferredCuisine      1500 non-null   object
#  7   TimeOfVisit           1500 non-null   object
#  8   GroupSize             1500 non-null   int64
#  9   DiningOccasion        1500 non-null   object
#  10  MealType              1500 non-null   object
#  11  OnlineReservation     1500 non-null   int64
#  12  DeliveryOrder         1500 non-null   int64
#  13  LoyaltyProgramMember  1500 non-null   int64
#  14  WaitTime              1500 non-null   float64
# ...

# %%
#null values

data.isnull()
# Out:
#       CustomerID    Age  Gender  Income  VisitFrequency  AverageSpend  \
# 0          False  False   False   False           False         False
# 1          False  False   False   False           False         False
# 2          False  False   False   False           False         False
# 3          False  False   False   False           False         False
# 4          False  False   False   False           False         False
# ...          ...    ...     ...     ...             ...           ...
# 1495       False  False   False   False           False         False
# 1496       False  False   False   False           False         False
# 1497       False  False   False   False           False         False
# 1498       False  False   False   False           False         False
# 1499       False  False   False   False           False         False
#
#       PreferredCuisine  TimeOfVisit  GroupSize  DiningOccasion  MealType  \
# ...

# %%
data.isnull().sum()
# Out:
# CustomerID              0
# Age                     0
# Gender                  0
# Income                  0
# VisitFrequency          0
# AverageSpend            0
# PreferredCuisine        0
# TimeOfVisit             0
# GroupSize               0
# DiningOccasion          0
# MealType                0
# OnlineReservation       0
# DeliveryOrder           0
# LoyaltyProgramMember    0
# WaitTime                0
# ServiceRating           0
# FoodRating              0
# AmbianceRating          0
# HighSatisfaction        0
# dtype: int64

# %%
data[data.index.isin(range(75,85))]
# Out:
#     CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 75         729   30  Female   37083        Monthly    174.694211
# 76         730   53  Female  101003         Rarely     71.268491
# 77         731   40  Female   33239        Monthly    169.872140
# 78         732   65    Male  132529         Weekly     56.684496
# 79         733   42    Male   31187         Rarely     27.396141
# 80         734   66  Female   31296        Monthly    180.705607
# 81         735   55    Male  147219        Monthly     58.956709
# 82         736   31    Male   81176        Monthly    175.607972
# 83         737   35  Female   62674        Monthly     54.499075
# 84         738   19  Female   63136        Monthly     16.503124
#
#    PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 75           Indian   Breakfast          9    Celebration  Takeaway
# 76          Italian   Breakfast          1    Celebration   Dine-in
# ...

# %%
data['AverageSpend'].head(15)
# Out:
# 0      27.829142
# 1     115.408622
# 2     106.693771
# 3      43.508508
# 4     148.084627
# 5     111.064696
# 6     120.236707
# 7     160.979098
# 8      56.558632
# 9      65.753455
# 10     39.235383
# 11    132.994918
# 12    156.130808
# 13     46.136865
# 14     88.939098
# Name: AverageSpend, dtype: float64

# %%
data[['TimeOfVisit','PreferredCuisine']].head(15)
# Out:
#    TimeOfVisit PreferredCuisine
# 0    Breakfast          Chinese
# 1       Dinner         American
# 2       Dinner         American
# 3        Lunch           Indian
# 4    Breakfast          Chinese
# 5       Dinner          Chinese
# 6        Lunch           Indian
# 7       Dinner          Mexican
# 8    Breakfast           Indian
# 9        Lunch          Italian
# 10   Breakfast         American
# 11      Dinner          Italian
# 12   Breakfast         American
# 13      Dinner          Italian
# 14       Lunch         American

# %%
data['Gender'].head(30)==0
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# Name: Gender, dtype: bool

# %%
dt=data['AmbianceRating'].value_counts()
print(dt)
# Out:
# AmbianceRating
# 1    324
# 5    317
# 2    298
# 4    293
# 3    268
# Name: count, dtype: int64

# %%
dt1=data['ServiceRating'].value_counts()
print(dt1)
# Out:
# ServiceRating
# 5    322
# 3    302
# 4    295
# 1    292
# 2    289
# Name: count, dtype: int64

# %%
df=data.head(1500)
data1=df.sort_index(ascending=False).head()
data1.sort_values(by='AverageSpend',ascending=False)
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 1498        2152   24    Male   27970         Weekly    196.363626
# 1496        2150   37  Female  133506         Weekly    190.991911
# 1499        2153   51    Male  148333         Weekly    171.119498
# 1495        2149   39    Male  114857        Monthly    163.015254
# 1497        2151   46    Male  119159        Monthly    150.088604
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 1498          Italian      Dinner          6         Casual   Dine-in
# 1496          Italian       Lunch          4         Casual  Takeaway
# 1499          Chinese   Breakfast          4         Casual   Dine-in
# 1495         American       Lunch          2       Business   Dine-in
# 1497         American       Lunch          4         Casual   Dine-in
#
#       OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# ...

# %%
data.describe()
# Out:
#         CustomerID          Age         Income  AverageSpend    GroupSize  \
# count  1500.000000  1500.000000    1500.000000   1500.000000  1500.000000
# mean   1403.500000    43.832000   85921.890000    105.659004     5.035333
# std     433.157015    14.967157   38183.051749     52.381849     2.558864
# min     654.000000    18.000000   20012.000000     10.306127     1.000000
# 25%    1028.750000    31.750000   52444.000000     62.287907     3.000000
# 50%    1403.500000    44.000000   85811.000000    104.626408     5.000000
# 75%    1778.250000    57.000000  119159.250000    148.649330     7.000000
# max    2153.000000    69.000000  149875.000000    199.973527     9.000000
#
#        OnlineReservation  DeliveryOrder  LoyaltyProgramMember     WaitTime  \
# count        1500.000000    1500.000000           1500.000000  1500.000000
# mean            0.296667       0.405333              0.480000    30.163550
# std             0.456941       0.491120              0.499766    17.214184
# ...

# %%
import matplotlib.pyplot as plt
Age_data=data['Age'].head(10)
HighSatisfaction_data=data['HighSatisfaction'].head(10)

plt.pie(Age_data,labels=HighSatisfaction_data, autopct='%1.6f%%', startangle=100)
plt.title("Pie chart for Age and HighSatisfaction ")
plt.show()

# %%
import matplotlib.pyplot as plt
labels = data['HighSatisfaction'].head(5)
sizes= data['WaitTime'].head(5)
plt.pie(sizes, labels=labels, autopct="%1.0f%%", startangle=100)
plt.title("Pie chart For HighSatisfaction and waitTime")
plt.show()

# %%
dt=data[data.index.isin(range(775,790))]
dt1=dt.loc[dt['Age']>= 30]
sns.barplot(data=dt1 ,x='ServiceRating',y='Age')
# Out:
# <Axes: xlabel='ServiceRating', ylabel='Age'>

# %%
dt=data[data.index.isin(range(896,956))]
data2=dt.loc[dt['Income']>= 2000]
sns.barplot(data=data2 ,x='PreferredCuisine',y='Income')
# Out:
# <Axes: xlabel='PreferredCuisine', ylabel='Income'>

# %%
dt=data[data.index.isin(range(2,400))]
d2=dt.loc[dt['WaitTime']>=40.00]
sns.lineplot(data=d2 ,x='HighSatisfaction',y='WaitTime')
# Out:
# <Axes: xlabel='HighSatisfaction', ylabel='WaitTime'>

# %%
data.head()
# Out:
#    CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0         654   35    Male   83380         Weekly     27.829142
# 1         655   19    Male   43623         Rarely    115.408622
# 2         656   41  Female   83737         Weekly    106.693771
# 3         657   43    Male   96768         Rarely     43.508508
# 4         658   55  Female   67937        Monthly    148.084627
#
#   PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0          Chinese   Breakfast          3       Business  Takeaway
# 1         American      Dinner          1         Casual   Dine-in
# 2         American      Dinner          6    Celebration   Dine-in
# 3           Indian       Lunch          1    Celebration   Dine-in
# 4          Chinese   Breakfast          1       Business  Takeaway
#
#    OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 0                  0              1                     1  43.523929
# ...

# %%
dt= data.tail(50)
dt4=dt[(dt['WaitTime']>=40)&(dt['GroupSize']>=3)]
sns.lineplot(x='GroupSize' ,y='WaitTime',data=dt4)
# Out:
# <Axes: xlabel='GroupSize', ylabel='WaitTime'>

# %%
dt=data.tail(35)
df= dt[(dt['AverageSpend']>=75)&(dt['FoodRating']>=4)]
sns.lineplot(x='FoodRating',y='AverageSpend', data=df)
# Out:
# <Axes: xlabel='FoodRating', ylabel='AverageSpend'>

# %%
df=data[data.index.isin(range(1010,1030))]
sns.countplot(x='AmbianceRating', data=df)
# Out:
# <Axes: xlabel='AmbianceRating', ylabel='count'>

# %%
dt=data.head(20)
sns.pairplot(dt[['Age', 'Gender', 'Income', 'VisitFrequency','AverageSpend','FoodRating','HighSatisfaction']])

# %%
dt= data.head(20)
dt2=dt[dt['HighSatisfaction']==2]
sns.stripplot(x='LoyaltyProgramMember' ,y='HighSatisfaction',data=dt2)
# Out:
# <Axes: >

# %%
data[''].value_counts()
